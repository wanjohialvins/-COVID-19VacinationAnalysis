# %%
# Import the pandas library and give it an alias 'pd'
import pandas as pd

# Import the numpy library and give it an alias 'np'
import numpy as np

# Import the seaborn library and give it an alias 'sns'
import seaborn as sns

# Import the matplotlib.pyplot library and give it an alias 'plt'
import matplotlib.pyplot as plt

# %%
# Read data from a CSV file using pandas. The file is named 'Sample - Superstore.csv'.
# The 'encoding' parameter is set to 'latin-1' to handle non-UTF-8 encoded characters.
df = pd.read_csv('Sample - Superstore.csv', encoding='latin-1')

# Display the first few rows (default is 5) of the DataFrame 'df' to inspect the data.
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Obtain information about the DataFrame 'df' and its data distribution.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Generate summary statistics for the data in the DataFrame 'df'.
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#Visualization of Shipmode, Segment and City
# Create a figure with a size of 12x8 inches.
plt.figure(figsize=(12, 8))

# Create a subplot grid of 2 rows and 2 columns, and select the first subplot.
plt.subplot(2, 2, 1)

# Create a countplot to visualize the distribution of 'Ship Mode'.
sns.countplot(data=df, x='Ship Mode')
plt.title('Ship Mode Distribution')

# Select the second subplot.
plt.subplot(2, 2, 2)

# Create a countplot to visualize the distribution of 'Segment'.
sns.countplot(data=df, x='Segment')
plt.title('Segment Distribution')

# Select the third subplot.
plt.subplot(2, 2, 3)

# Create a countplot to visualize the top 10 cities by orders.
# The 'order' parameter ensures that the cities are ordered by the number of orders.
sns.countplot(data=df, y='City', order=df['City'].value_counts().index[:10])
plt.title('Top 10 Cities by Orders')

# Automatically adjust subplot positions for better layout.
plt.tight_layout()

# Display the visualizations.
plt.show()
# Out:
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Visualization of Sales,Quanityt,Discount, and Profit 
# Create a new figure with a size of 12x8 inches.
plt.figure(figsize=(12, 8))

# Select the first subplot.
plt.subplot(2, 2, 1)

# Create a histogram (histplot) to visualize the distribution of 'Sales' with 20 bins.
sns.histplot(data=df, x='Sales', bins=20)
plt.title('Sales Distribution')

# Select the second subplot.
plt.subplot(2, 2, 2)

# Create a histogram (histplot) to visualize the distribution of 'Quantity' with 20 bins.
sns.histplot(data=df, x='Quantity', bins=20)
plt.title('Quantity Distribution')

# Select the third subplot.
plt.subplot(2, 2, 3)

# Create a histogram (histplot) to visualize the distribution of 'Discount' with 20 bins.
sns.histplot(data=df, x='Discount', bins=20)
plt.title('Discount Distribution')

# Select the fourth subplot.
plt.subplot(2, 2, 4)

# Create a histogram (histplot) to visualize the distribution of 'Profit' with 20 bins.
sns.histplot(data=df, x='Profit', bins=20)
plt.title('Profit Distribution')

# Automatically adjust subplot positions for better layout.
plt.tight_layout()

# Display the visualizations.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 6 line 3
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # Visualization of Sales,Quanityt,Discount, and Profit
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> # Create a new figure with a size of 12x8 inches.
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(12, 8))
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> # Select the first subplot.
# ...

# %%
#Data splitting and subset creation
# Create subsets for cities 'Philadelphia' and 'Los Angeles' with quantities greater than 5.
subset1 = df[(df['City'] == 'Philadelphia') & (df['Quantity'] > 5)]
subset2 = df[(df['City'] == 'Los Angeles') & (df['Quantity'] > 5)]

# %%
#Summary Statistics calculations
# Calculate summary statistics for the sales distribution in each subset.
summary_subset1 = subset1['Sales'].describe()
summary_subset2 = subset2['Sales'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 8 line 3
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> #Summary Statistics calculations
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> # Calculate summary statistics for the sales distribution in each subset.
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> summary_subset1 = subset1['Sales'].describe()
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X10sZmlsZQ%3D%3D?line=3'>4</a> summary_subset2 = subset2['Sales'].describe()
#
# NameError: name 'subset1' is not defined

# %%
#Visualization of Sales Distribution
# Create a figure with a size of 12x6 inches.
plt.figure(figsize=(12, 6))

# Create subplots for visualizing the sales distribution in each subset.
plt.subplot(1, 2, 1)
sns.histplot(data=subset1, x='Sales', bins=20)
plt.title('Sales Distribution in Philadelphia (Quantity > 5)')

plt.subplot(1, 2, 2)
sns.histplot(data=subset2, x='Sales', bins=20)
plt.title('Sales Distribution in Los Angeles (Quantity > 5)')

# Automatically adjust subplot positions for better layout.
plt.tight_layout()

# Display the visualizations.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 9 line 3
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> #Visualization of Sales Distribution
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> # Create a figure with a size of 12x6 inches.
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(12, 6))
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> # Create subplots for visualizing the sales distribution in each subset.
# ...

# %%
#Display Summary Statistics
# Display summary statistics for each subset.
print("Summary Statistics for Philadelphia Subset:")
print(summary_subset1)
print("Summary Statistics for Los Angeles Subset:")
print(summary_subset2)
# Out:
# Summary Statistics for Philadelphia Subset:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 10 line 4
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> #Display Summary Statistics
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> # Display summary statistics for each subset.
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X12sZmlsZQ%3D%3D?line=2'>3</a> print("Summary Statistics for Philadelphia Subset:")
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X12sZmlsZQ%3D%3D?line=3'>4</a> print(summary_subset1)
# ...

# %%
#Data preparation and correlations
# Step 1: Filter the DataFrame to include only numeric columns
numeric_columns = df.select_dtypes(include='number')

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 11 line 3
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> #Data preparation and correlations
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> # Step 1: Filter the DataFrame to include only numeric columns
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> numeric_columns = df.select_dtypes(include='number')
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> # Calculate the correlation matrix
# ...

# %%
#Identify Features with the strongest correlations
# Step 2: Identify the features with the strongest positive and negative correlations with 'Sales'
# Filter out the 'Sales' column
correlation_with_sales = correlation_matrix['Sales'].drop('Sales')

# Find the feature with the strongest positive correlation
strongest_positive_corr_feature = correlation_with_sales.idxmax()

# Find the feature with the strongest negative correlation
strongest_negative_corr = correlation_matrix['Sales'].nsmallest(1).index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 12 line 4
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> #Identify Features with the strongest correlations
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> # Step 2: Identify the features with the strongest positive and negative correlations with 'Sales'
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X14sZmlsZQ%3D%3D?line=2'>3</a> # Filter out the 'Sales' column
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> correlation_with_sales = correlation_matrix['Sales'].drop('Sales')
# ...

# %%
#Create Scatterplots to visualize relationships
# Step 3: Create plots to represent these relationships
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
sns.scatterplot(data=df, x=strongest_positive_corr_feature, y='Sales')
plt.title(f'Positive Correlation: {strongest_positive_corr_feature} vs. Sales')

plt.subplot(1, 2, 2)
sns.scatterplot(data=df, x=strongest_negative_corr[0], y='Sales')
plt.title(f'Negative Correlation: {strongest_negative_corr[0]} vs. Sales')

# Automatically adjust subplot positions for better layout.
plt.tight_layout()

# Display the scatterplots.
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 13 line 3
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> #Create Scatterplots to visualize relationships
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X15sZmlsZQ%3D%3D?line=1'>2</a> # Step 3: Create plots to represent these relationships
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X15sZmlsZQ%3D%3D?line=2'>3</a> plt.figure(figsize=(12, 6))
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X15sZmlsZQ%3D%3D?line=3'>4</a> plt.subplot(1, 2, 1)
# ...

# %%
# Step 1: Choose two significant columns
col1 = 'Profit'
col2 = 'Discount'

# Step 2: Create the new feature by subtracting one column from the other
df['Net_profit'] = df[col1] - df[col2]

# Step 3: Visualize the relationship between the new feature and sales
plt.scatter(df['Net_profit'], df['Sales'])
plt.xlabel('New Profit')
plt.ylabel('Sales')
plt.title('Relationship between Net profit and Sales')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/eragon/Documents/Flatiron/Sales/analysis.ipynb Cell 14 line 6
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X16sZmlsZQ%3D%3D?line=2'>3</a> col2 = 'Discount'
#       <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X16sZmlsZQ%3D%3D?line=4'>5</a> # Step 2: Create the new feature by subtracting one column from the other
# ----> <a href='vscode-notebook-cell:/home/eragon/Documents/Flatiron/Sales/analysis.ipynb#X16sZmlsZQ%3D%3D?line=5'>6</a> df['Net_profit'] = df[col1] - df[col2]
#
# NameError: name 'df' is not defined
